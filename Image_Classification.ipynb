# %% [markdown]
# <a href="https://colab.research.google.com/github/fridayyy3000/mini-project/blob/main/Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing_image_downloader

# !mkdir images 

from bing_image_downloader import downloader
downloader.download("super cars",limit =30,output_dir='images',adult_filter_off=True)

from bing_image_downloader import downloader
downloader.download("beautiful sunflowers",limit =30,output_dir='images',adult_filter_off=True)

from bing_image_downloader import downloader
downloader.download("UEFA Soccer Ball",limit =30,output_dir='images',adult_filter_off=True)

from bing_image_downloader import downloader
downloader.download("ice cream cone",limit =30,output_dir='images',adult_filter_off=True)
# Out:
# Collecting bing_image_downloader
#   Downloading https://files.pythonhosted.org/packages/0d/bf/537a61030b84ae4cd5022d5c7b014fd9bc3ce7c02358919153a6658a61d3/bing_image_downloader-1.0.4-py3-none-any.whl
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.0.4
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://carsoid.com/wp-content/uploads/2018/03/Best-Looking-Blacked-Out-Supercars.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://digitalsynopsis.com/wp-content/uploads/2014/06/supercar-wallpapers-gumpert-apollo-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://pictures.topspeed.com/IMG/jpg/201406/1967-toyota-2000-gt-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.supercars.net/blog/wp-content/uploads/2020/10/2020-Bugatti-Bolide-Concept-002-2160-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://wallpapershome.com/images/wallpapers/lamborghini-egoista-1080x1920-supercar-concept-lamborghini-sports-car-2215.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://wallpapershome.com/images/wallpapers/mclaren-720s-1920x1080-supercar-2019-cars-4k-20157.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://4kwallpapers.com/images/wallpapers/bugatti-veyron-grand-sport-vitesse-supercars-2560x1440-1410.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://besthqwallpapers.com/Uploads/12-8-2019/100856/thumb-4k-nissan-gt-r-night-r34-supercars.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://www.hdcarwallpapers.com/download/lamborghini_aventador_supercar-1600x900.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://richtelevision.com/wp-content/uploads/2020/08/1597837336_maxresdefault-1024x576.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://cdn.motor1.com/images/mgl/Gw67A/s3/2021-audi-rs6-avant-shot-by-auditography.jpg
# [Error]Invalid image, not saving https://cdn.motor1.com/images/mgl/Gw67A/s3/2021-audi-rs6-avant-shot-by-auditography.jpg
#
# [!] Issue getting: https://cdn.motor1.com/images/mgl/Gw67A/s3/2021-audi-rs6-avant-shot-by-auditography.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #11 from https://www.topcarrating.com/ferrari/2014-ferrari-f60-america-5.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 12 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #12 from https://carsoid.com/wp-content/uploads/2018/03/Best-Looking-Blacked-Out-Supercars.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://digitalsynopsis.com/wp-content/uploads/2014/06/supercar-wallpapers-gumpert-apollo-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://pictures.topspeed.com/IMG/jpg/201406/1967-toyota-2000-gt-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.supercars.net/blog/wp-content/uploads/2020/10/2020-Bugatti-Bolide-Concept-002-2160-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://wallpapershome.com/images/wallpapers/lamborghini-egoista-1080x1920-supercar-concept-lamborghini-sports-car-2215.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://wallpapershome.com/images/wallpapers/mclaren-720s-1920x1080-supercar-2019-cars-4k-20157.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://4kwallpapers.com/images/wallpapers/bugatti-veyron-grand-sport-vitesse-supercars-2560x1440-1410.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://besthqwallpapers.com/Uploads/12-8-2019/100856/thumb-4k-nissan-gt-r-night-r34-supercars.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from http://www.hdcarwallpapers.com/download/lamborghini_aventador_supercar-1600x900.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://richtelevision.com/wp-content/uploads/2020/08/1597837336_maxresdefault-1024x576.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://cdn.motor1.com/images/mgl/Gw67A/s3/2021-audi-rs6-avant-shot-by-auditography.jpg
# [Error]Invalid image, not saving https://cdn.motor1.com/images/mgl/Gw67A/s3/2021-audi-rs6-avant-shot-by-auditography.jpg
#
# [!] Issue getting: https://cdn.motor1.com/images/mgl/Gw67A/s3/2021-audi-rs6-avant-shot-by-auditography.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #22 from https://www.topcarrating.com/ferrari/2014-ferrari-f60-america-5.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed
jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://www.peters.com.au/wp-content/uploads/2020/05/Drumstick_ClassicVanilla_HW.png
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://www.doyouremember.co.uk/uploads/W2YrgIV811138666_467075566790990_8064308684721678494_n.jpg
# [Error]Invalid image, not saving https://www.doyouremember.co.uk/uploads/W2YrgIV811138666_467075566790990_8064308684721678494_n.jpg
#
# [!] Issue getting: https://www.doyouremember.co.uk/uploads/W2YrgIV811138666_467075566790990_8064308684721678494_n.jpg
# [!] Error:: No active exception to reraise
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 11 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #21 from https://www.dispatch.com/storyimage/OH/20170713/NEWS/170719386/AR/0/AR-170719386.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://www.tablefortwoblog.com/wp-content/uploads/2013/09/espress-chocolate-chip-ice-cream-tablefortwoblog-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from http://www.mintedandvintage.com/collections/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/p/o/porcelain_ice_cream_jar.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://thefancy-media-ec3.thefancy.com/original/20110902/260782783_854ed8477672.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://www.seriouseats.com/images/2014/06/20140613-Chocolate-Dip-kingcone-vicky-wasik-14.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://www.campfiremarshmallows.com/wp-content/uploads/2016/07/marshmallow-dipped-ice-cream-cones.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://assets.pinshape.com/uploads/image/file/116692/container_ice-cream-emoji-or-poop-on-a-cone-3d-printing-116692.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from http://farm6.staticflickr.com/5445/7227446516_2bfabf111c_z.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://half-heartedfanatic.com/wp-content/uploads/sites/2/2020/02/20200201-130424-smurfs-ice-cream-missing-arm-after.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://www.al.com/resizer/pybRnmM_6ScWwJ7rkMVGuaIjrBE=/1280x0/smart/advancelocal-adapter-image-uploads.s3.amazonaws.com/image.al.com/home/bama-media/width2048/img/bargain-mom/photo/balloon-ice-cream-conesjpg-d1517e4bffe7a630.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.
#
# ===============================================

# %%
# processing
# 1. resizise
# 2. flatten


import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize

target = []
images = []
flat_data = []

DATADIR = '/content/images'
CATEGORIES = ['super cars', 'UEFA Soccer Ball','ice cream cone']

for category in CATEGORIES:
  class_num = CATEGORIES.index(category) #label encoding values
  path = os.path.join(DATADIR,category) # create path to use all images

  for img in os.listdir(path):
    img_array=imread(os.path.join(path,img))
    # plt.imshow(img_array)
    img_resize = resize(img_array,(150,150,3))  # Normalises the value from 0 to 1
    flat_data.append(img_resize.flatten())
    images.append(img_resize)
    target.append(class_num)

flat_data = np.array(flat_data)
target = np.array(target)
images = np.array(images)

# %%
# split data from training and testing

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(flat_data,target,test_size=0.3,random_state=109)


from sklearn.model_selection import GridSearchCV
from sklearn import svm
param_grid = [
              {'C':[1,10,100,1000],'kernel':['linear']},
              {'C':[1,10,100,1000],'gamma':[0.001,0.0001],'kernel':['rbf']},]

svc = svm.SVC(probability=True)
clf = GridSearchCV(svc,param_grid)
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=True, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#                          {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001],
#                           'kernel': ['rbf']}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
y_pred = clf.predict(x_test)
y_pred

y_test
# Out:
# array([1, 0, 1, 2, 2, 1, 0, 1, 1, 0, 1, 0, 1, 2, 2, 1, 2, 1, 0, 1, 2, 2,
#        2, 0, 0, 0, 1])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix 
accuracy_score(y_test,y_pred)


confusion_matrix(y_pred,y_test)
# Out:
# array([[ 8,  0,  0],
#        [ 0, 11,  2],
#        [ 0,  0,  6]])

# %%
# save the modle using pickle library

import pickle
pickle.dump(clf,open('img_model.p','wb'))

# %%
model = pickle.load(open('img_model.p','rb'))

# testing a brand new image

flat_data = []
url = input("Enter your URL")
img = imread(url)
img_resize = resize(img,(150,150,3))
flat_data.append(img_resize.flatten())
flat_data = np.array(flat_data)
print(img.shape)
plt.imshow(img_resize)
y_out = model.predict(flat_data)
y_out = CATEGORIES[y_out[0]]
print(f'PREDICTED OUTPUT:{y_out}')
# Out:
# Enter your URLhttps://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Strawberry_ice_cream_cone_%285076899310%29.jpg/220px-Strawberry_ice_cream_cone_%285076899310%29.jpg
# (331, 220, 3)
# PREDICTED OUTPUT:ice cream cone
